# %%
a = [100,200,500,800,900,1000]
b = [1,4,5,1000]

# %%
temp=0
for i in range(len(a)):
    for j in range(len(b)):
        if b[j]<=len(a):
            print(a[j])
            break
print(temp)
# Out:
# 100
# 100
# 100
# 100
# 100
# 100
# 0

# %%
temp=0
for i in b:
    if i>=len(a):
        print(i)
    print(a[i-1])
# Out:
# 100
# 800
# 900
# 1000
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/f2/dyht95tj14z8rvh8sf6v0xrh0000gn/T/ipykernel_58347/3671010104.py in <module>
#       3     if i>=len(a):
#       4         print(i)
# ----> 5     print(a[i-1])
#       6
#       7
#
# IndexError: list index out of range

# %%
import pyautogui as pg

# %%
pip install pyautogui
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7fdf39080670>: Failed to establish a new connection: [Errno 51] Network is unreachable')': /simple/pyautogui/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7fdf39080c40>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/pyautogui/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7fdf39080ca0>: Failed to establish a new connection: [Errno 51] Network is unreachable')': /simple/pyautogui/
# ...
#   Using cached PyAutoGUI-0.9.53.tar.gz (59 kB)
# ...

# %%
import time

# %%
for i in range(10):
    pg.write("call utha")
    pg.press('enter')
